# %%
import pandas as pd

# %%
casts = pd.read_csv('cast.csv')

# %%
casts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75001 entries, 0 to 75000
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      75001 non-null  object
#  1   year       75001 non-null  int64
#  2   name       75001 non-null  object
#  3   type       75001 non-null  object
#  4   character  75001 non-null  object
#  5   n          46035 non-null  float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 3.4+ MB

# %%
casts.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
for index, row in casts.iterrows():
    print(index, ':', row.title, ',', row['name'])
# Out:
# 0 : Closet Monster , Buffy #1
# 1 : Suuri illusioni , Homo $
# 2 : Battle of the Sexes , $hutter
# 3 : Secret in Their Eyes , $hutter
# 4 : Steve Jobs , $hutter
# 5 : Straight Outta Compton , $hutter
# 6 : Straight Outta Compton , $hutter
# 7 : For Thy Love 2 , Bee Moe $lim
# 8 : Lapis, Ballpen at Diploma, a True to Life Journey , Jori ' Danilo' Jurado Jr.
# 9 : Desire (III) , Syaiful 'Ariffin
# 10 : When the Man Went South , Taipaleti 'Atu'ake
# 11 : Little Angel (Angelita) , Michael 'babeepower' Viera
# 12 : Mixing Nia , Michael 'babeepower' Viera
# 13 : The Replacements , Steven 'Bear'Boyd
# 14 : All Out Dysfunktion! , Kirlew 'bliss' Vilbon
# 15 : Gook , Kirlew 'bliss' Vilbon
# 16 : My Song for You , George 'Bootsy' Thomas
# 17 : My Song for You , George 'Bootsy' Thomas
# 18 : Hustle Beach , Pete 'Boretta' Torres
# 19 : Mariano Mison... NBI , Joseph 'Byron' Sese
# 20 : Natas es Satan , Ramon 'Cartucho' Pena
# 21 : B-Girl , Jesse 'Casper' Brown
# ...

# %%
casts['n']
# Out:
# 0        31.0
# 1        22.0
# 2        10.0
# 3         NaN
# 4         NaN
#          ...
# 74996    11.0
# 74997     NaN
# 74998    20.0
# 74999     NaN
# 75000    25.0
# Name: n, Length: 75001, dtype: float64

# %%
casts['n'].isnull() #n에 NaN인 값 찾기
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 74996    False
# 74997     True
# 74998    False
# 74999     True
# 75000    False
# Name: n, Length: 75001, dtype: bool

# %%
casts['n'].notnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 74996     True
# 74997    False
# 74998     True
# 74999    False
# 75000     True
# Name: n, Length: 75001, dtype: bool

# %%
casts[casts['n'].notnull()] #null이 아닌것만 찾기
# Out:
#                                                    title  year  \
# 0                                         Closet Monster  2015
# 1                                        Suuri illusioni  1985
# 2                                    Battle of the Sexes  2017
# 8      Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 10                               When the Man Went South  2014
# ...                                                  ...   ...
# 74994                                         180 moires  2010
# 74995                                   Ama de se thelei  2009
# 74996                           Mia fora kai ena... moro  2011
# 74998                                 Festival of Lights  2010
# 75000                                    Fugitive Pieces  2007
#
#                              name     type               character     n
# 0                        Buffy #1    actor                 Buffy 4  31.0
# ...

# %%
casts['n'].fillna(0, inplace = True) #NaN값을 0으로 채움

# %%
casts
# Out:
#                           title  year                        name     type  \
# 0                Closet Monster  2015                    Buffy #1    actor
# 1               Suuri illusioni  1985                      Homo $    actor
# 2           Battle of the Sexes  2017                     $hutter    actor
# 3          Secret in Their Eyes  2015                     $hutter    actor
# 4                    Steve Jobs  2015                     $hutter    actor
# ...                         ...   ...                         ...      ...
# 74996  Mia fora kai ena... moro  2011     Penelope Anastasopoulou  actress
# 74997         The Magician King  2004       Tiannah Anastassiades  actress
# 74998        Festival of Lights  2010             Zoe Anastassiou  actress
# 74999                Toxic Tutu  2016             Zoe Anastassiou  actress
# 75000           Fugitive Pieces  2007  Anastassia Anastassopoulou  actress
#
#                      character     n
# ...

# %%
casts[casts.title.str.startswith('Maa')] #Maa로 시작하는 제목 찾기
# Out:
#                              title  year                  name     type  \
# 1489                         Maaro  2011          Abbas (VIII)    actor
# 6695                    Maarek hob  2004          Robert Abyad    actor
# 17319                       Maalik  2016      Farhan Ally Agha    actor
# 21678        Maa on syntinen laulu  1973    Niiles-Jouni Aikio    actor
# 21680        Maa on syntinen laulu  1973            Uula Aikio    actor
# 22667             Maan Gaye Ustaad  1981                  Ajit    actor
# 22986                 Maa kap Phra  2006       Pisan Akaraseni    actor
# 32315                  Maathi Yosi  2010           Alex (CXIV)    actor
# 32429                     Maad Dad  2013             Lalu Alex    actor
# 37445                  Maala Yogam  1990                Aliyar    actor
# 45518        Maa Nanna Chiranjeevi  2010                Alutit    actor
# 50944                   Maarek hob  2004        Colette Abboud  actress
# ...

# %%
casts[casts.title.str.contains('Star')] #Star가 포함된 제목 찾기
# Out:
#                                                   title  year  \
# 263                                   Porn Star Zombies  2009
# 481    Bob Hope's All-Star Look at TV's Prime Time Wars  1980
# 482                   Dickie Roberts: Former Child Star  2003
# 1905                               The Last Starfighter  1984
# 1978                                       Starry Night  1999
# ...                                                 ...   ...
# 72735              Starship Valiant: The Ties That Bind  2017
# 73046                       Starting Out in the Evening  2007
# 73053                    Cultivision (Collapsing Stars)  2002
# 73063                                   Starsky & Hutch  2004
# 73158                                    The North Star  2016
#
#                   name     type         character     n
# 263          A.J. (XV)    actor           Trinity   6.0
# 481       Willie Aames    actor           Himself   0.0
# ...

# %%
casts.year.value_counts() #casts['year'].value_counts()도 동일 동작. 같은 값(연도)이 몇번있는지
# Out:
# 2016    3841
# 2015    3439
# 2014    3309
# 2013    3110
# 2012    3011
#         ...
# 2019      16
# 1913      10
# 2020       4
# 1912       3
# 2023       3
# Name: year, Length: 110, dtype: int64

# %%
casts.groupby(['year']).size() #연도별로 그룹
# Out:
# year
# 1912       3
# 1913      10
# 1914      61
# 1915      82
# 1916     116
#         ...
# 2017    2159
# 2018     158
# 2019      16
# 2020       4
# 2023       3
# Length: 110, dtype: int64

# %%
casts.groupby(['year','type']).size() #연도, 성별 별로 그룹
# Out:
# year  type
# 1912  actor       1
#       actress     2
# 1913  actor       9
#       actress     1
# 1914  actor      38
#                  ..
# 2019  actress     3
# 2020  actor       3
#       actress     1
# 2023  actor       1
#       actress     2
# Length: 220, dtype: int64
